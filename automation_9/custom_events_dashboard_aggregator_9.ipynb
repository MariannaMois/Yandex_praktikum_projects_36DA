# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-исследования" data-toc-modified-id="Описание-исследования-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Описание исследования</a></span></li><li><span><a href="#Цель-исследования." data-toc-modified-id="Цель-исследования.-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Цель исследования.</a></span></li><li><span><a href="#Задачи-исследования." data-toc-modified-id="Задачи-исследования.-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Задачи исследования.</a></span></li><li><span><a href="#Исходные-данные." data-toc-modified-id="Исходные-данные.-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Исходные данные.</a></span></li></ul></li></ul></li><li><span><a href="#Часть-1.-Подготовка-коннекции-к-базе" data-toc-modified-id="Часть-1.-Подготовка-коннекции-к-базе-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Часть 1. Подготовка коннекции к базе</a></span></li><li><span><a href="#Часть-2.-Анализ-данных" data-toc-modified-id="Часть-2.-Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Часть 2. Анализ данных</a></span></li><li><span><a href="#Часть-3.--Подготовка-презентации" data-toc-modified-id="Часть-3.--Подготовка-презентации-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Часть 3.  Подготовка презентации</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта
#
# #### Описание исследования
# Автоматизация анализа пользовательского взаимодействия с карточками статей  "Яндекс.Дзен".
#
# _____
# #### Цель исследования.
# Создание дашборда для анализа взаимодействия пользователей с системой.
#
# _____
# #### Задачи исследования.
#
# 1. Создать коннекцию к базе.
# 2. В Tableau Public на основе файла dash_visits.csv сформировать дашборд в соответствии с макетом;
# ![image.png](attachment:image.png)
# 3. Подготовить презентацию, ответив на вопросы менеджеров, используя дашборд:
# * сколько взаимодействий пользователей с карточками происходит в системе с разбивкой по темам карточек?
# * как много карточек генерируют источники с разными темами?
# * как соотносятся темы карточек и темы источников?.
#
# _____
# #### Исходные данные.
#
# * cырые данные о событиях взаимодействия пользователей с карточками (таблица log_raw);
# * база данных, в которой будут храниться агрегированные данные: дополнительные агрегированные таблицы в БД zen.
# ______

# %% [markdown]
# ##  Часть 1. Подготовка коннекции к базе

# %%
# импортируем библиотеки
import pandas as pd
from sqlalchemy import create_engine

db_config = {'user': 'praktikum_student', # имя пользователя
            'pwd': 'Sdf4$2;d-d30pp', # пароль
            'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
            'port': 6432, # порт подключения
            'db': 'data-analyst-zen-project-db'} # название базы данных

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                db_config['pwd'],
                                                db_config['host'],
                                                db_config['port'],
                                                db_config['db'])

engine = create_engine(connection_string)

# %%
query = '''
            SELECT * FROM dash_visits
        '''
dash_visits = pd.io.sql.read_sql(query, con = engine)

dash_visits.to_csv('dash_visits.csv', index = False)

dash_visits.head(10)
# Out:
#    record_id item_topic source_topic age_segment                  dt  visits
# 0    1040597     Деньги         Авто       18-25 2019-09-24 18:32:00       3
# 1    1040598     Деньги         Авто       18-25 2019-09-24 18:35:00       1
# 2    1040599     Деньги         Авто       18-25 2019-09-24 18:54:00       4
# 3    1040600     Деньги         Авто       18-25 2019-09-24 18:55:00      17
# 4    1040601     Деньги         Авто       18-25 2019-09-24 18:56:00      27
# 5    1040602     Деньги         Авто       18-25 2019-09-24 18:57:00      22
# 6    1040603     Деньги         Авто       18-25 2019-09-24 18:58:00      24
# 7    1040604     Деньги         Авто       18-25 2019-09-24 18:59:00      20
# 8    1040605     Деньги         Авто       18-25 2019-09-24 19:00:00       5
# 9    1040606     Деньги         Авто       26-30 2019-09-24 18:29:00       1

# %% [markdown]
# ##  Часть 2. Анализ данных

# %% [markdown]
# Tableau Public  - https://public.tableau.com/app/profile/mariannmois/viz/__16505492176510/Dashboard1

# %% [markdown]
# ##  Часть 3.  Подготовка презентации

# %% [markdown]
# Презентация  - https://disk.yandex.ru/i/-jo8ez7dXN1rlw
